# %%
from datetime import date
from datetime import datetime,timedelta
import os
import shutil
import pickle

# %% [markdown]
# # 1.일일뉴스

# %%
daily_news_image_url=[
    "https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/daily_news/all/pie_graph.PNG?raw=true",
    "https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/daily_news/all/bar_graph.PNG?raw=true",
    "https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/daily_news/all/word_cloud.PNG?raw=true",
    "https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/daily_news/all/thermometer.PNG?raw=true",
    "https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/daily_news/positive/ratio_graph.PNG?raw=true",
    "https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/daily_news/positive/bar_graph.PNG?raw=true",
    "https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/daily_news/positive/word_cloud.PNG?raw=true",
    "https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/daily_news/negative/ratio_graph.PNG?raw=true",
    "https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/daily_news/negative/bar_graph.PNG?raw=true",
    "https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/daily_news/negative/word_cloud.PNG?raw=true"
]

# %%
F = str(datetime.now() + timedelta(hours=9)).replace("-","").replace(":","").replace(" ","")[:12]
os.mkdir(F)

# %%
shutil.move('daily_news', F)
# Out:
# '202208100117\\daily_news'

# %%
daily_news_image_url[0][:63]
# Out:
# 'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/'

# %%
daily_news_image_url_re = []
for i in daily_news_image_url:
    daily_news_image_url_re.append(i[:63]+F+'/'+i[63:])

# %%
daily_news_image_url_re
# Out:
# ['https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/202208100117/daily_news/all/pie_graph.PNG?raw=true',
#  'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/202208100117/daily_news/all/bar_graph.PNG?raw=true',
#  'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/202208100117/daily_news/all/word_cloud.PNG?raw=true',
#  'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/202208100117/daily_news/all/thermometer.PNG?raw=true',
#  'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/202208100117/daily_news/positive/ratio_graph.PNG?raw=true',
#  'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/202208100117/daily_news/positive/bar_graph.PNG?raw=true',
#  'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/202208100117/daily_news/positive/word_cloud.PNG?raw=true',
#  'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/202208100117/daily_news/negative/ratio_graph.PNG?raw=true',
# ...

# %%
with open('daily_news_image_url_re.pickle', 'wb') as f:
    pickle.dump(daily_news_image_url_re,f)

# %% [markdown]
# # 2.업종별

# %%
shutil.move('sector', F)
# Out:
# '202208100117\\sector'

# %%
df_sector = {'Food': ['097950', '271560', '000080', '004370', '005300'],
             'Clothing': ['093050', '020000', '105630', '001070'],
             'Chemical': ['051910', '096770', '010950', '051900', '090430'],
             'Medicine': ['207940', '068270', '000100', '128940'],
             'Non_Metal': ['003670', '003410', '010780'],
             'Metal': ['005490', '010130', '004020', '016380', '001230'],
             'Machine': ['034020', '018880', '241560', '112610'],
             'Electronic': ['005930', '000660', '006400', '066570'],
             'Construction': ['000720', '006360', '047040', '051600'],
             'Transport': ['011200', '003490', '086280', '180640', '028670'],
             'Distribution': ['028260', '023530', '282330', '139480', '004170'],
             'Power': ['015760', '036460', '017390'],
             'Tele': ['017670', '030200', '032640'],
             'Finance': ['003550', '000810', '006800'],
             'Brokerage': ['005940', '016360', '008560', '039490'],
             'Insurer': ['032830', '005830', '000060', '001450'],
             'Service': ['035420', '035720', '018260', '036570'],
             'Manufacturer': ['005380', '000270', '012330', '033780', '009150']}

# %%
a = 'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/sector/'

# %%
df_sector_image_url = []
for i,j in df_sector.items():
    b = ''
    b = a+i+'/'
    for k in j:
        c=''
        c = b+k+'/'
        df_sector_image_url.append(c+'ratio_graph.PNG?raw=true')
        df_sector_image_url.append(c+'bar_graph.PNG?raw=true')
        df_sector_image_url.append(c+'word_cloud.PNG?raw=true')
        df_sector_image_url.append(c+'thermometer.PNG?raw=true')

# %%
df_sector_image_url
# Out:
# ['https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/sector/Food/097950/ratio_graph.PNG?raw=true',
#  'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/sector/Food/097950/bar_graph.PNG?raw=true',
#  'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/sector/Food/097950/word_cloud.PNG?raw=true',
#  'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/sector/Food/097950/thermometer.PNG?raw=true',
#  'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/sector/Food/271560/ratio_graph.PNG?raw=true',
#  'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/sector/Food/271560/bar_graph.PNG?raw=true',
#  'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/sector/Food/271560/word_cloud.PNG?raw=true',
#  'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/sector/Food/271560/thermometer.PNG?raw=true',
# ...

# %%
len(df_sector_image_url)//4
# Out:
# 74

# %%
df_sector_image_url[0][:63]
# Out:
# 'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/'

# %%
df_sector_image_url_re = []
for i in df_sector_image_url:
    df_sector_image_url_re.append(i[:63]+F+'/'+i[63:])

# %%
df_sector_image_url_re
# Out:
# ['https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/202208100117/sector/Food/097950/ratio_graph.PNG?raw=true',
#  'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/202208100117/sector/Food/097950/bar_graph.PNG?raw=true',
#  'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/202208100117/sector/Food/097950/word_cloud.PNG?raw=true',
#  'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/202208100117/sector/Food/097950/thermometer.PNG?raw=true',
#  'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/202208100117/sector/Food/271560/ratio_graph.PNG?raw=true',
#  'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/202208100117/sector/Food/271560/bar_graph.PNG?raw=true',
#  'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/202208100117/sector/Food/271560/word_cloud.PNG?raw=true',
# ...

# %%
len(df_sector_image_url_re)
# Out:
# 296

# %%
df_sector_image_url_re_div = []
in_l =[df_sector_image_url_re[0]]
for i in range(1,len(df_sector_image_url_re)+1):
    if i%4 != 0:
        in_l.append(df_sector_image_url_re[i])
    else:
        df_sector_image_url_re_div.append(in_l)
        in_l =[]
        if i%4 == 0 and i <len(df_sector_image_url_re):
            in_l =[df_sector_image_url_re[i]]

# %%
df_sector_image_url_re_div
# Out:
# [['https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/202208100117/sector/Food/097950/ratio_graph.PNG?raw=true',
#   'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/202208100117/sector/Food/097950/bar_graph.PNG?raw=true',
#   'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/202208100117/sector/Food/097950/word_cloud.PNG?raw=true',
#   'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/202208100117/sector/Food/097950/thermometer.PNG?raw=true'],
#  ['https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/202208100117/sector/Food/271560/ratio_graph.PNG?raw=true',
#   'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/202208100117/sector/Food/271560/bar_graph.PNG?raw=true',
#   'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/202208100117/sector/Food/271560/word_cloud.PNG?raw=true',
# ...

# %%
len(df_sector_image_url_re_div)
# Out:
# 74

# %%
df_sector_l = ['CJ제일제당분석',
 '오리온분석',
 '하이트진로분석',
 '농심분석',
 '롯데칠성분석',
 'LF분석',
 '한섬분석',
 '한세실업분석',
 '대한방직분석',
 'LG화학분석',
 'SK이노베이션분석',
 'S-Oil분석',
 'LG생활건강분석',
 '아모레퍼시픽분석',
 '삼성바이오로직스분석',
 '셀트리온분석',
 '유한양행분석',
 '한미약품분석',
 '포스코케미칼분석',
 '쌍용C&E분석',
 '아이에스동서분석',
 'POSCO홀딩스분석',
 '고려아연분석',
 '현대제철분석',
 'KG스틸분석',
 '동국제강분석',
 '두산에너빌리티분석',
 '한온시스템분석',
 '두산밥캣분석',
 '씨에스윈드분석',
 '삼성전자분석',
 'SK하이닉스분석',
 '삼성SDI분석',
 'LG전자분석',
 '현대건설분석',
 'GS건설분석',
 '대우건설분석',
 '한전KPS분석',
 'HMM분석',
 '대한항공분석',
 '현대글로비스분석',
 '한진칼분석',
 '팬오션분석',
 '삼성물산분석',
 '롯데쇼핑분석',
 'BGF리테일분석',
 '이마트분석',
 '신세계분석',
 '한국전력분석',
 '한국가스공사분석',
 '서울가스분석',
 'SK테레콤분석',
 'KT분석',
 'LG유플러스분석',
 'LG분석',
 '삼성화재분석',
 '미래에셋증권분석',
 'NH투자증권분석',
 '삼성증권분석',
 '메리츠증권분석',
 '키움증권분석',
 '삼성생명분석',
 'DB손해보험분석',
 '메리츠화재분석',
 '현대해상분석',
 'Naver분석',
 '카카오분석',
 '삼성에스디에스분석',
 '엔씨소프트분석',
 '현대차분석',
 '기아분석',
 '현대모비스분석',
 'KT&G분석',
 '삼성전기분석']

# %%
df_sector_image_url = {}
for i in range(len(df_sector_l)):
    df_sector_image_url[df_sector_l[i]]=df_sector_image_url_re_div[i]

# %%
df_sector_image_url
# Out:
# {'CJ제일제당분석': ['https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/202208100117/sector/Food/097950/ratio_graph.PNG?raw=true',
#   'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/202208100117/sector/Food/097950/bar_graph.PNG?raw=true',
#   'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/202208100117/sector/Food/097950/word_cloud.PNG?raw=true',
#   'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/202208100117/sector/Food/097950/thermometer.PNG?raw=true'],
#  '오리온분석': ['https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/202208100117/sector/Food/271560/ratio_graph.PNG?raw=true',
#   'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/202208100117/sector/Food/271560/bar_graph.PNG?raw=true',
#   'https://github.com/Parksemo/FINAL_PROJECT_goormIDE/blob/master/202208100117/sector/Food/271560/word_cloud.PNG?raw=true',
# ...

# %%
with open('df_sector_image_url.pickle', 'wb') as f:
    pickle.dump(df_sector_image_url,f)
