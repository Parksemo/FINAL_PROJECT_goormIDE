# %%
import pickle
import numpy as np
import pandas as pd
import os
import warnings
warnings.filterwarnings('ignore')
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
with open('df_sector_UTD.pickle','rb') as f:
    df_sector_UTD = pickle.load(f)
with open('certificated_stock_dic.pickle','rb') as f:
    certificated_stock_dic = pickle.load(f)
with open('X_scaler_dic.pickle','rb' ) as f:
    X_scaler_dic = pickle.load(f)

# %% [markdown]
# # 스케일링 하기

# %%
from sklearn.preprocessing import MinMaxScaler
scale_cols = ['거래량','시가','고가', '저가','종가']

X_UTD_scaled_dic = {}
for sector_name, stock_list in certificated_stock_dic.items():
    X_UTD_scaled_dic[sector_name] = {}
    for stock_code in stock_list:
        X_scaler = X_scaler_dic[sector_name][stock_code]
        X_UTD_scaled = X_scaler.transform(df_sector_UTD[sector_name][stock_code][scale_cols])
        X_UTD_scaled_dic[sector_name][stock_code] = pd.DataFrame(X_UTD_scaled,index = df_sector_UTD[sector_name][stock_code].index,columns=scale_cols)

# %%
X_UTD_scaled_dic
# Out:
# {'Food': {'097950':            거래량        시가        고가        저가        종가
#   0     0.067022  0.070501  0.069091  0.072549  0.069549
#   1     0.069804  0.074212  0.085455  0.076471  0.080827
#   2     0.084692  0.083488  0.090909  0.088235  0.099624
#   3     0.132782  0.092764  0.092727  0.080392  0.082707
#   4     0.052191  0.089054  0.092727  0.096078  0.099624
#   ...        ...       ...       ...       ...       ...
#   2998  0.044953  0.740260  0.718182  0.754902  0.731203
#   2999  0.030882  0.723562  0.703636  0.752941  0.725564
#   3000  0.032486  0.716141  0.701818  0.754902  0.733083
#   3001  0.022287  0.727273  0.709091  0.754902  0.721805
#   3002 -0.014010  0.721707  0.707273  0.762745  0.729323
#
#   [3003 rows x 5 columns]},
#  'Clothing': {},
#  'Chemical': {'090430':            거래량        시가        고가        저가        종가
#   0     0.073101  0.032240  0.030336  0.029278  0.031206
#   1     0.055527  0.034186  0.034399  0.032973  0.035107
#   2     0.166126  0.036409  0.037107  0.032405  0.033993
#   3     0.109703  0.038633  0.037378  0.034110  0.033157
#   4     0.089586  0.034186  0.037920  0.034963  0.033714
#   ...        ...       ...       ...       ...       ...
#   2998  0.092581  0.120345  0.115655  0.118818  0.116746
#   2999  0.078042  0.116176  0.112947  0.114554  0.113959
#   3000  0.125784  0.113396  0.115655  0.115975  0.115352
#   3001  0.108040  0.117565  0.115655  0.115975  0.115352
#   3002  0.011539  0.116176  0.114301  0.117396  0.116746
#
#   [3003 rows x 5 columns]},
#  'Medicine': {},
#  'Non_Metal': {'003410':            거래량        시가        고가        저가        종가
#   0     0.004713  0.043014  0.038611  0.045311  0.041754
#   1     0.005005  0.043014  0.038004  0.045038  0.038997
#   2     0.015182  0.039625  0.034847  0.039973  0.033220
#   3     0.011810  0.036887  0.033026  0.039699  0.033220
#   4     0.009664  0.035975  0.035697  0.040657  0.037553
#   ...        ...       ...       ...       ...       ...
#   2998  0.005035  0.765250  0.719281  0.803285  0.778493
#   2999  0.004602  0.774374  0.722924  0.804654  0.775867
#   3000  0.005850  0.773071  0.719281  0.804654  0.766675
#   3001  0.014556  0.776981  0.752064  0.818344  0.791623
#   3002  0.000814  0.791319  0.735066  0.826557  0.790310
#
#   [3003 rows x 5 columns]},
#  'Metal': {'010130':            거래량        시가        고가        저가        종가
#   0     0.274515 -0.081779 -0.100575 -0.092784 -0.088150
#   1     0.350876 -0.068867 -0.083333 -0.075110 -0.066474
#   2     0.275811 -0.053085 -0.068966 -0.058910 -0.046243
#   3     0.155017 -0.038737 -0.061782 -0.047128 -0.041908
#   4     0.148333 -0.038737 -0.048851 -0.042710 -0.031792
#   ...        ...       ...       ...       ...       ...
#   2998  0.108115  0.761836  0.780172  0.780560  0.789017
#   2999  0.034048  0.770445  0.750000  0.777614  0.767341
#   3000  0.058244  0.771879  0.748563  0.764359  0.763006
#   3001  0.035330  0.767575  0.748563  0.777614  0.771676
#   3002  0.039118  0.799139  0.813218  0.820324  0.838150
#
#   [3003 rows x 5 columns]},
#  'Machine': {},
#  'Electronic': {},
#  'Construction': {'047040':            거래량        시가        고가        저가        종가
#   0     0.010650  0.448187  0.448451  0.457181  0.459038
#   1     0.011719  0.456822  0.452694  0.463329  0.466840
#   2     0.013188  0.474957  0.461179  0.469477  0.461638
#   3     0.008892  0.469775  0.464574  0.479139  0.476376
#   4     0.033119  0.482729  0.524820  0.495828  0.536194
#   ...        ...       ...       ...       ...       ...
#   2998  0.047102  0.121762  0.120916  0.127800  0.124404
#   2999  0.038548  0.126943  0.117522  0.126921  0.116602
#   3000  0.027109  0.117444  0.113280  0.123408  0.116602
#   3001  0.038594  0.124352  0.115825  0.124286  0.114868
#   3002  0.006540  0.120898  0.115825  0.126921  0.120069
#
#   [3003 rows x 5 columns]},
#  'Transport': {'028670':            거래량        시가        고가        저가        종가
#   0     0.001079  0.795388  0.786976  0.797635  0.787549
#   1     0.001008  0.802697  0.783425  0.790275  0.780349
#   2     0.001315  0.795388  0.783425  0.793955  0.783948
#   3     0.002392  0.810005  0.794075  0.793955  0.780349
#   4     0.001855  0.799042  0.794075  0.797635  0.794752
#   ...        ...       ...       ...       ...       ...
#   2998  0.067707  0.008091  0.008175  0.008295  0.008061
#   2999  0.072626  0.008238  0.008203  0.008442  0.008118
#   3000  0.051681  0.007945  0.007777  0.008060  0.007859
#   3001  0.049631  0.007887  0.007834  0.008060  0.008089
#   3002  0.004546  0.008091  0.007834  0.008354  0.008061
#
#   [3003 rows x 5 columns]},
#  'Distribution': {'028260':            거래량        시가        고가        저가        종가
#   0     1.191870  0.242890  0.282624  0.216878  0.314286
#   1     0.416631  0.335127  0.379957  0.371308  0.448980
#   2     0.402593  0.465796  0.495314  0.481013  0.489796
#   3     0.259700  0.442736  0.437635  0.451477  0.493878
#   4     0.122309  0.469639  0.448450  0.493671  0.477551
#   ...        ...       ...       ...       ...       ...
#   1873  0.009693  0.354343  0.315068  0.375527  0.363265
#   1874  0.011040  0.338970  0.307859  0.367089  0.363265
#   1875  0.006887  0.335127  0.311464  0.375527  0.359184
#   1876  0.009286  0.346656  0.311464  0.362869  0.359184
#   1877 -0.007779  0.338970  0.304254  0.371308  0.363265
#
#   [1878 rows x 5 columns]},
#  'Power': {},
#  'Tele': {'032640':            거래량        시가        고가        저가        종가
#   0     0.101921  0.261053  0.257826  0.270504  0.272467
#   1     0.115648  0.277193  0.259937  0.281295  0.268887
#   2     0.280580  0.277193  0.257826  0.276259  0.270319
#   3     0.085510  0.273684  0.253605  0.271942  0.251701
#   4     0.026921  0.258947  0.243757  0.271223  0.251701
#   ...        ...       ...       ...       ...       ...
#   2998  0.006612  0.585965  0.567358  0.600719  0.584676
#   2999  0.003911  0.585965  0.567358  0.597122  0.581096
#   3000  0.015974  0.585965  0.570876  0.600719  0.588256
#   3001  0.009130  0.585965  0.567358  0.600719  0.584676
#   3002 -0.008628  0.585965  0.570876  0.604317  0.591837
#
#   [3003 rows x 5 columns]},
#  'Finance': {'006800':            거래량        시가        고가        저가        종가
#   0     0.033813  0.564089  0.587785  0.580795  0.603062
#   1     0.010589  0.600778  0.598922  0.606732  0.598495
#   2     0.012786  0.605397  0.590002  0.611419  0.593876
#   3     0.016232  0.614530  0.605624  0.630273  0.619149
#   4     0.050383  0.623716  0.636817  0.644386  0.637519
#   ...        ...       ...       ...       ...       ...
#   2998  0.006231  0.011417  0.008567  0.012250  0.010898
#   2999  0.008255  0.008822  0.005543  0.007456  0.006746
#   3000  0.005092  0.005708  0.004031  0.008522  0.007265
#   3001  0.007026  0.008822  0.006551  0.011184  0.008822
#   3002 -0.002136  0.008822  0.011086  0.012782  0.015568
#
#   [3003 rows x 5 columns]},
#  'Brokerage': {'005940':            거래량        시가        고가        저가        종가
#   0     0.070620  0.407284  0.448164  0.442749  0.459218
#   1     0.080332  0.435366  0.469979  0.462820  0.472203
#   2     0.041919  0.460321  0.457476  0.476131  0.459218
#   3     0.053981  0.454066  0.473105  0.489511  0.475382
#   4     0.099371  0.460321  0.498046  0.502822  0.498106
#   ...        ...       ...       ...       ...       ...
#   2998  0.023015  0.099036  0.096379  0.109415  0.102124
#   2999  0.018060  0.093172  0.091821  0.101052  0.096037
#   3000  0.009291  0.088611  0.092472  0.104537  0.100771
#   3001  0.018494  0.094475  0.095728  0.108021  0.105505
#   3002 -0.015075  0.097081  0.099635  0.113597  0.110239
#
#   [3003 rows x 5 columns],
#   '008560':            거래량        시가        고가        저가        종가
#   0     0.017536  0.049170  0.049241  0.051256  0.051227
#   1     0.011618  0.052130  0.049880  0.051939  0.050564
#   2     0.008092  0.050650  0.049880  0.052793  0.052056
#   3     0.021263  0.053610  0.052918  0.055015  0.052719
#   4     0.034779  0.053610  0.054996  0.055869  0.056532
#   ...        ...       ...       ...       ...       ...
#   2998  0.012733  0.684427  0.683133  0.711259  0.696950
#   2999  0.020828  0.687716  0.671143  0.701862  0.681200
#   3000  0.016505  0.673738  0.668745  0.698445  0.691147
#   3001  0.018882  0.685249  0.671942  0.701862  0.685345
#   3002  0.001080  0.685249  0.675140  0.706134  0.700265
#
#   [3003 rows x 5 columns]},
#  'Insurer': {},
#  'Service': {},
#  'Manufacturer': {'012330':            거래량        시가        고가        저가        종가
#   0     0.190319  0.093812  0.103030  0.091837  0.103030
#   1     0.222511  0.107784  0.105051  0.089796  0.101010
#   2     0.172335  0.103792  0.105051  0.104082  0.111111
#   3     0.161957  0.121756  0.123232  0.126531  0.127273
#   4     0.112214  0.123752  0.129293  0.122449  0.129293
#   ...        ...       ...       ...       ...       ...
#   2998  0.062853  0.241517  0.244444  0.242857  0.242424
#   2999  0.064888  0.239521  0.238384  0.240816  0.238384
#   3000  0.105862  0.239521  0.250505  0.248980  0.256566
#   3001  0.076030  0.259481  0.252525  0.253061  0.250505
#   3002 -0.015922  0.251497  0.246465  0.255102  0.244444
#
#   [3003 rows x 5 columns]}}

# %%
#윈도우 사이즈
WINDOW_SIZE = 10
# X에 대한 윈도우 함수 설정값
X_size = WINDOW_SIZE
X_shift = 1
X_stride = 1
# y에 대한 윈도우 함수 설정값
y_size = 1
y_shift = 1
y_stride = 1

batch_size = 32

# %% [markdown]
# # 2. 모델 불러오기

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv1D, Lambda
from tensorflow.keras.losses import Huber
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
model_dic ={}
for sector_name, stock_list in certificated_stock_dic.items():
    model_dic[sector_name] = {}
    for stock_code in stock_list:
        model_dic[sector_name][stock_code] = Sequential([
            # 1차원 feature map 생성
            Conv1D(filters=32, kernel_size=5,
                   padding="causal",
                   activation="relu",
                   #feature의 개수 3개
                   input_shape=[WINDOW_SIZE, 5]),
            # LSTM
            LSTM(16, activation='tanh'),
            Dense(16, activation="relu"),
            Dense(3,activation='softmax'),
        ])

# %%
with open('filename_dic.pickle', 'rb') as f:
    filename_dic = pickle.load(f)

# %%
filename_dic
# Out:
# {'Food': {'097950': 'MC\\Food\\097950ckeckpointer.ckpt',
#   '271560': 'MC\\Food\\271560ckeckpointer.ckpt',
#   '000080': 'MC\\Food\\000080ckeckpointer.ckpt',
#   '004370': 'MC\\Food\\004370ckeckpointer.ckpt',
#   '005300': 'MC\\Food\\005300ckeckpointer.ckpt'},
#  'Clothing': {'093050': 'MC\\Clothing\\093050ckeckpointer.ckpt',
#   '020000': 'MC\\Clothing\\020000ckeckpointer.ckpt',
#   '105630': 'MC\\Clothing\\105630ckeckpointer.ckpt',
#   '001070': 'MC\\Clothing\\001070ckeckpointer.ckpt'},
#  'Chemical': {'051910': 'MC\\Chemical\\051910ckeckpointer.ckpt',
#   '096770': 'MC\\Chemical\\096770ckeckpointer.ckpt',
#   '010950': 'MC\\Chemical\\010950ckeckpointer.ckpt',
#   '051900': 'MC\\Chemical\\051900ckeckpointer.ckpt',
#   '090430': 'MC\\Chemical\\090430ckeckpointer.ckpt'},
#  'Medicine': {'207940': 'MC\\Medicine\\207940ckeckpointer.ckpt',
#   '068270': 'MC\\Medicine\\068270ckeckpointer.ckpt',
#   '000100': 'MC\\Medicine\\000100ckeckpointer.ckpt',
#   '128940': 'MC\\Medicine\\128940ckeckpointer.ckpt'},
#  'Non_Metal': {'003670': 'MC\\Non_Metal\\003670ckeckpointer.ckpt',
#   '003410': 'MC\\Non_Metal\\003410ckeckpointer.ckpt',
#   '010780': 'MC\\Non_Metal\\010780ckeckpointer.ckpt'},
#  'Metal': {'005490': 'MC\\Metal\\005490ckeckpointer.ckpt',
#   '010130': 'MC\\Metal\\010130ckeckpointer.ckpt',
#   '004020': 'MC\\Metal\\004020ckeckpointer.ckpt',
#   '016380': 'MC\\Metal\\016380ckeckpointer.ckpt',
#   '001230': 'MC\\Metal\\001230ckeckpointer.ckpt'},
#  'Machine': {'034020': 'MC\\Machine\\034020ckeckpointer.ckpt',
#   '018880': 'MC\\Machine\\018880ckeckpointer.ckpt',
#   '241560': 'MC\\Machine\\241560ckeckpointer.ckpt',
#   '112610': 'MC\\Machine\\112610ckeckpointer.ckpt'},
#  'Electronic': {'005930': 'MC\\Electronic\\005930ckeckpointer.ckpt',
#   '000660': 'MC\\Electronic\\000660ckeckpointer.ckpt',
#   '006400': 'MC\\Electronic\\006400ckeckpointer.ckpt',
#   '066570': 'MC\\Electronic\\066570ckeckpointer.ckpt'},
#  'Construction': {'000720': 'MC\\Construction\\000720ckeckpointer.ckpt',
#   '006360': 'MC\\Construction\\006360ckeckpointer.ckpt',
#   '047040': 'MC\\Construction\\047040ckeckpointer.ckpt',
#   '051600': 'MC\\Construction\\051600ckeckpointer.ckpt'},
#  'Transport': {'011200': 'MC\\Transport\\011200ckeckpointer.ckpt',
#   '003490': 'MC\\Transport\\003490ckeckpointer.ckpt',
#   '086280': 'MC\\Transport\\086280ckeckpointer.ckpt',
#   '180640': 'MC\\Transport\\180640ckeckpointer.ckpt',
#   '028670': 'MC\\Transport\\028670ckeckpointer.ckpt'},
#  'Distribution': {'028260': 'MC\\Distribution\\028260ckeckpointer.ckpt',
#   '023530': 'MC\\Distribution\\023530ckeckpointer.ckpt',
#   '282330': 'MC\\Distribution\\282330ckeckpointer.ckpt',
#   '139480': 'MC\\Distribution\\139480ckeckpointer.ckpt',
#   '004170': 'MC\\Distribution\\004170ckeckpointer.ckpt'},
#  'Power': {'015760': 'MC\\Power\\015760ckeckpointer.ckpt',
#   '036460': 'MC\\Power\\036460ckeckpointer.ckpt',
#   '017390': 'MC\\Power\\017390ckeckpointer.ckpt'},
#  'Tele': {'017670': 'MC\\Tele\\017670ckeckpointer.ckpt',
#   '030200': 'MC\\Tele\\030200ckeckpointer.ckpt',
#   '032640': 'MC\\Tele\\032640ckeckpointer.ckpt'},
#  'Finance': {'003550': 'MC\\Finance\\003550ckeckpointer.ckpt',
#   '000810': 'MC\\Finance\\000810ckeckpointer.ckpt',
#   '006800': 'MC\\Finance\\006800ckeckpointer.ckpt'},
#  'Brokerage': {'005940': 'MC\\Brokerage\\005940ckeckpointer.ckpt',
#   '016360': 'MC\\Brokerage\\016360ckeckpointer.ckpt',
#   '008560': 'MC\\Brokerage\\008560ckeckpointer.ckpt',
#   '039490': 'MC\\Brokerage\\039490ckeckpointer.ckpt'},
#  'Insurer': {'032830': 'MC\\Insurer\\032830ckeckpointer.ckpt',
#   '005830': 'MC\\Insurer\\005830ckeckpointer.ckpt',
#   '000060': 'MC\\Insurer\\000060ckeckpointer.ckpt',
#   '001450': 'MC\\Insurer\\001450ckeckpointer.ckpt'},
#  'Service': {'035420': 'MC\\Service\\035420ckeckpointer.ckpt',
#   '035720': 'MC\\Service\\035720ckeckpointer.ckpt',
#   '018260': 'MC\\Service\\018260ckeckpointer.ckpt',
#   '036570': 'MC\\Service\\036570ckeckpointer.ckpt'},
#  'Manufacturer': {'005380': 'MC\\Manufacturer\\005380ckeckpointer.ckpt',
#   '000270': 'MC\\Manufacturer\\000270ckeckpointer.ckpt',
#   '012330': 'MC\\Manufacturer\\012330ckeckpointer.ckpt',
#   '033780': 'MC\\Manufacturer\\033780ckeckpointer.ckpt',
#   '009150': 'MC\\Manufacturer\\009150ckeckpointer.ckpt'}}

# %%
for_linux = {}
for sector_name, sector_name_dic in filename_dic.items():
    for_linux[sector_name] = {}
    for stock_code, filename in sector_name_dic.items():
        linux_filename = filename.replace('\\','/')
        for_linux[sector_name][stock_code] = linux_filename

# %%
for_linux
# Out:
# {'Food': {'097950': 'MC/Food/097950ckeckpointer.ckpt',
#   '271560': 'MC/Food/271560ckeckpointer.ckpt',
#   '000080': 'MC/Food/000080ckeckpointer.ckpt',
#   '004370': 'MC/Food/004370ckeckpointer.ckpt',
#   '005300': 'MC/Food/005300ckeckpointer.ckpt'},
#  'Clothing': {'093050': 'MC/Clothing/093050ckeckpointer.ckpt',
#   '020000': 'MC/Clothing/020000ckeckpointer.ckpt',
#   '105630': 'MC/Clothing/105630ckeckpointer.ckpt',
#   '001070': 'MC/Clothing/001070ckeckpointer.ckpt'},
#  'Chemical': {'051910': 'MC/Chemical/051910ckeckpointer.ckpt',
#   '096770': 'MC/Chemical/096770ckeckpointer.ckpt',
#   '010950': 'MC/Chemical/010950ckeckpointer.ckpt',
#   '051900': 'MC/Chemical/051900ckeckpointer.ckpt',
#   '090430': 'MC/Chemical/090430ckeckpointer.ckpt'},
#  'Medicine': {'207940': 'MC/Medicine/207940ckeckpointer.ckpt',
#   '068270': 'MC/Medicine/068270ckeckpointer.ckpt',
#   '000100': 'MC/Medicine/000100ckeckpointer.ckpt',
#   '128940': 'MC/Medicine/128940ckeckpointer.ckpt'},
#  'Non_Metal': {'003670': 'MC/Non_Metal/003670ckeckpointer.ckpt',
#   '003410': 'MC/Non_Metal/003410ckeckpointer.ckpt',
#   '010780': 'MC/Non_Metal/010780ckeckpointer.ckpt'},
#  'Metal': {'005490': 'MC/Metal/005490ckeckpointer.ckpt',
#   '010130': 'MC/Metal/010130ckeckpointer.ckpt',
#   '004020': 'MC/Metal/004020ckeckpointer.ckpt',
#   '016380': 'MC/Metal/016380ckeckpointer.ckpt',
#   '001230': 'MC/Metal/001230ckeckpointer.ckpt'},
#  'Machine': {'034020': 'MC/Machine/034020ckeckpointer.ckpt',
#   '018880': 'MC/Machine/018880ckeckpointer.ckpt',
#   '241560': 'MC/Machine/241560ckeckpointer.ckpt',
#   '112610': 'MC/Machine/112610ckeckpointer.ckpt'},
#  'Electronic': {'005930': 'MC/Electronic/005930ckeckpointer.ckpt',
#   '000660': 'MC/Electronic/000660ckeckpointer.ckpt',
#   '006400': 'MC/Electronic/006400ckeckpointer.ckpt',
#   '066570': 'MC/Electronic/066570ckeckpointer.ckpt'},
#  'Construction': {'000720': 'MC/Construction/000720ckeckpointer.ckpt',
#   '006360': 'MC/Construction/006360ckeckpointer.ckpt',
#   '047040': 'MC/Construction/047040ckeckpointer.ckpt',
#   '051600': 'MC/Construction/051600ckeckpointer.ckpt'},
#  'Transport': {'011200': 'MC/Transport/011200ckeckpointer.ckpt',
#   '003490': 'MC/Transport/003490ckeckpointer.ckpt',
#   '086280': 'MC/Transport/086280ckeckpointer.ckpt',
#   '180640': 'MC/Transport/180640ckeckpointer.ckpt',
#   '028670': 'MC/Transport/028670ckeckpointer.ckpt'},
#  'Distribution': {'028260': 'MC/Distribution/028260ckeckpointer.ckpt',
#   '023530': 'MC/Distribution/023530ckeckpointer.ckpt',
#   '282330': 'MC/Distribution/282330ckeckpointer.ckpt',
#   '139480': 'MC/Distribution/139480ckeckpointer.ckpt',
#   '004170': 'MC/Distribution/004170ckeckpointer.ckpt'},
#  'Power': {'015760': 'MC/Power/015760ckeckpointer.ckpt',
#   '036460': 'MC/Power/036460ckeckpointer.ckpt',
#   '017390': 'MC/Power/017390ckeckpointer.ckpt'},
#  'Tele': {'017670': 'MC/Tele/017670ckeckpointer.ckpt',
#   '030200': 'MC/Tele/030200ckeckpointer.ckpt',
#   '032640': 'MC/Tele/032640ckeckpointer.ckpt'},
#  'Finance': {'003550': 'MC/Finance/003550ckeckpointer.ckpt',
#   '000810': 'MC/Finance/000810ckeckpointer.ckpt',
#   '006800': 'MC/Finance/006800ckeckpointer.ckpt'},
#  'Brokerage': {'005940': 'MC/Brokerage/005940ckeckpointer.ckpt',
#   '016360': 'MC/Brokerage/016360ckeckpointer.ckpt',
#   '008560': 'MC/Brokerage/008560ckeckpointer.ckpt',
#   '039490': 'MC/Brokerage/039490ckeckpointer.ckpt'},
#  'Insurer': {'032830': 'MC/Insurer/032830ckeckpointer.ckpt',
#   '005830': 'MC/Insurer/005830ckeckpointer.ckpt',
#   '000060': 'MC/Insurer/000060ckeckpointer.ckpt',
#   '001450': 'MC/Insurer/001450ckeckpointer.ckpt'},
#  'Service': {'035420': 'MC/Service/035420ckeckpointer.ckpt',
#   '035720': 'MC/Service/035720ckeckpointer.ckpt',
#   '018260': 'MC/Service/018260ckeckpointer.ckpt',
#   '036570': 'MC/Service/036570ckeckpointer.ckpt'},
#  'Manufacturer': {'005380': 'MC/Manufacturer/005380ckeckpointer.ckpt',
#   '000270': 'MC/Manufacturer/000270ckeckpointer.ckpt',
#   '012330': 'MC/Manufacturer/012330ckeckpointer.ckpt',
#   '033780': 'MC/Manufacturer/033780ckeckpointer.ckpt',
#   '009150': 'MC/Manufacturer/009150ckeckpointer.ckpt'}}

# %%
for sector_name, stock_list in certificated_stock_dic.items():
    for stock_code in stock_list:
        if not stock_list:
            model_dic[sector_name][stock_code].load_weights(linux_filename[sector_name][stock_code])

# %%
model_dic
# Out:
# {'Food': {'097950': <tensorflow.python.keras.engine.sequential.Sequential at 0x1f3d250fc10>},
#  'Clothing': {},
#  'Chemical': {'090430': <tensorflow.python.keras.engine.sequential.Sequential at 0x1f3d2ac2b20>},
#  'Medicine': {},
#  'Non_Metal': {'003410': <tensorflow.python.keras.engine.sequential.Sequential at 0x1f3d2c973d0>},
#  'Metal': {'010130': <tensorflow.python.keras.engine.sequential.Sequential at 0x1f3d2f927c0>},
#  'Machine': {},
#  'Electronic': {},
#  'Construction': {'047040': <tensorflow.python.keras.engine.sequential.Sequential at 0x1f3d2f46a00>},
#  'Transport': {'028670': <tensorflow.python.keras.engine.sequential.Sequential at 0x1f3d2f07910>},
#  'Distribution': {'028260': <tensorflow.python.keras.engine.sequential.Sequential at 0x1f3d308bc70>},
#  'Power': {},
#  'Tele': {'032640': <tensorflow.python.keras.engine.sequential.Sequential at 0x1f3d25ac460>},
#  'Finance': {'006800': <tensorflow.python.keras.engine.sequential.Sequential at 0x1f3d2ed8940>},
#  'Brokerage': {'005940': <tensorflow.python.keras.engine.sequential.Sequential at 0x1f3d2b6daf0>,
#   '008560': <tensorflow.python.keras.engine.sequential.Sequential at 0x1f3d32418e0>},
#  'Insurer': {},
#  'Service': {},
#  'Manufacturer': {'012330': <tensorflow.python.keras.engine.sequential.Sequential at 0x1f3d2aa5760>}}

# %% [markdown]
# # 존재 항목별 tomorrow 예측하기

# %%
from datetime import date,datetime, timedelta
today = date.today()
tomorrow = today+timedelta(days=1, hours = 9)
tomorrow = tomorrow.isoformat()
tomorrow = tomorrow.replace('-','')[2:]
set_d = tomorrow
set_d
# Out:
# '220806'

# %%
with open('sector_name_kr.pickle','rb' ) as f:
    sector_name_kr = pickle.load(f)

# %%
sector_name_kr
# Out:
# {'Food': ['CJ제일제당', '오리온', '하이트진로', '농심', '롯데칠성'],
#  'Clothing': ['LF', '한섬', '한세실업', '대한방직'],
#  'Chemical': ['LG화학', 'SK이노베이션', 'S-Oil', 'LG생활건강', '아모레퍼시픽'],
#  'Medicine': ['삼성바이오로직스', '셀트리온', '유한양행', '한미약품'],
#  'Non_Metal': ['포스코케미칼', '쌍용C&E', '아이에스동서'],
#  'Metal': ['POSCO홀딩스', '고려아연', '현대제철', 'KG스틸', '동국제강'],
#  'Machine': ['두산에너빌리티', '한온시스템', '두산밥캣', '씨에스윈드'],
#  'Electronic': ['삼성전자', 'SK하이닉스', '삼성SDI', 'LG전자'],
#  'Construction': ['현대건설', 'GS건설', '대우건설', '한전KPS'],
#  'Transport': ['HMM', '대한항공', '현대글로비스', '한진칼', '팬오션'],
#  'Distribution': ['삼성물산', '롯데쇼핑', 'BGF리테일', '이마트', '신세계'],
#  'Power': ['한국전력', '한국가스공사', '서울가스'],
#  'Tele': ['SK텔레콤', 'KT', 'LG유플러스'],
#  'Finance': ['LG', '삼성화재', '미래에셋증권'],
#  'Brokerage': ['NH투자증권', '삼성증권', '메리츠증권', '키움증권'],
#  'Insurer': ['삼성생명', 'DB손해보험', '메리츠화재', '현대해상'],
#  'Service': ['NAVER', '카카오', '삼성에스디에스', '엔씨소프트'],
#  'Manufacturer': ['현대차', '기아', '현대모비스', 'KT&G', '삼성전기']}

# %%
pred_dic = {}
for sector_name, sector_model in model_dic.items():
    pred_dic[sector_name] = {}
    for stock_code, model in sector_model.items():
        pred_dic[sector_name][stock_code] = []
        data = tf.constant(np.expand_dims(np.array(X_UTD_scaled_dic[sector_name][stock_code].tail(10))[:10],axis=0))
        result = model.predict(data)
        print('-----------{0}-----------'.format(stock_code))
        up = f'상향할 확률 : {np.around(result[0][0]*100,1)}'
        down = f'하향할 확률 : {np.around(result[0][1]*100,1)}'
        sideways = f'횡보할 확률 : {np.around(result[0][2]*100,1)}'
        pred_dic[sector_name][stock_code].append(up)
        pred_dic[sector_name][stock_code].append(down)
        pred_dic[sector_name][stock_code].append(sideways)
        print(up)
        print(down)
        print(sideways)
# Out:
# -----------097950-----------
# 상향할 확률 : 35.9
# 하향할 확률 : 32.3
# 횡보할 확률 : 31.8
# -----------090430-----------
# 상향할 확률 : 34.4
# 하향할 확률 : 33.7
# 횡보할 확률 : 31.9
# -----------003410-----------
# 상향할 확률 : 43.2
# 하향할 확률 : 33.7
# 횡보할 확률 : 23.1
# -----------010130-----------
# 상향할 확률 : 34.3
# 하향할 확률 : 30.7
# 횡보할 확률 : 35.0
# -----------047040-----------
# 상향할 확률 : 34.0
# 하향할 확률 : 32.6
# 횡보할 확률 : 33.4
# -----------028670-----------
# 상향할 확률 : 33.4
# 하향할 확률 : 33.4
# 횡보할 확률 : 33.2
# -----------028260-----------
# 상향할 확률 : 37.8
# 하향할 확률 : 29.3
# 횡보할 확률 : 32.8
# -----------032640-----------
# 상향할 확률 : 35.7
# 하향할 확률 : 37.1
# 횡보할 확률 : 27.2
# -----------006800-----------
# 상향할 확률 : 33.4
# 하향할 확률 : 33.3
# 횡보할 확률 : 33.4
# -----------005940-----------
# 상향할 확률 : 33.4
# 하향할 확률 : 33.3
# 횡보할 확률 : 33.3
# -----------008560-----------
# 상향할 확률 : 36.8
# 하향할 확률 : 32.0
# 횡보할 확률 : 31.3
# -----------012330-----------
# 상향할 확률 : 30.8
# 하향할 확률 : 32.5
# 횡보할 확률 : 36.7

# %%
with open('pred_dic.pickle','wb' ) as f:
    pickle.dump(pred_dic,f)
